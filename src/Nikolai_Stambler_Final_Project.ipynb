# %% [markdown]
# <a href="https://colab.research.google.com/github/Niktennant/Titianic-Logisitic-Regression/blob/main/Nikolai_Stambler_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Title
# An Investigation into Titanic Survival Rates Based on Class and Companionship

# %% [markdown]
# # Introduction
#
# My project investigates the relationship between class and travel status (alone or with others) and survival of the 1912 Titanic disaster. This investigation uses data from individual passenger records from those aboard the Titanic. Class relates to the passenger class (first, second, third) that each passenger was in, while alone (No, yes) relates to wether the passenger boarded the Titanic with either a child, spouse, or parent.
#
# My investigation into the Titanic disaster meant I was looking at the deaths of many passengers. For me, it was important to not let these real human lives and deaths turn into just statistics and instead remain the human element of what I was analyzing.
#
#
# $\color{green}{\text{Research question:  }}$
#
#
# How class and embarking as a solo passenger or with companions affects survivability on the Titanic.
#
#
# ---

# %% [markdown]
# # Analysis
#
# To prepare my data for use I first dropped any columns that did not have relevance to my question. This left me with only four variables: survived, class, pclass, alone. My final step was combining pclass and class to create a more succinct dataframe.
#
# **Univariate (graphical and non-graphical)**
#
#
# | Covariance     | survived |  alone  | class |
# | ----------- | ----------- | -------- ||
# | survived     | 1.000000      | -0.204132 |-0.13741|
# | alone     |     -0.204132    | 1.000000 |0.055632|
# |class     |     -0.13741    | 0.055632 |1.000000|
#
# -
#
# | Correlation     | survived  |  alone    |class   |
# | ----------- | -----------   | --------  |--------|
# | survived    | 0.236973      | -0.048649 |-0.13741|
# | alone       |     -0.048649 | 0.239676  |0.055632|
# |class        |     -0.13741  | 0.055632  |0.699511|
#
# ![How Many Passengers were Alone.png](data:image/png;base64,...)![# of Third Class Passengers that Survived.png](data:image/png;base64,...)![# of Second Class Passengers that Survived.png](data:image/png;base64,...)![# of Passengers Who Survived (1 = yes: 0 = no).png](data:image/png;base64,...)![# of Passengers In each Class.png](data:image/png;base64,...)![# of first Class Passengers that Survived.png](data:image/png;base64,...)

# %% [markdown]
# My EDA showed that more passengers were alone that traveling with companions and that most people did not survive, with the lower the class the greater proportion of passengers who died - with first class being the only class were more people survived than died.
#
# Furthermore, most people were within third class, however, second class had less than first.
#
# There is a negative covariance between alone and survived, class and survived, and a positive covariance between class and alone. This indicates that as one of these variables changes the other changes inversely.
#
# There is a negative correlation between alone and survived, class and survived, and a positive correlation between alone and class. This indicates that as one of these variables changes the other changes in the same direction.
#
# Finally the value_counts of each variable showed there were 889 observations for each.

# %% [markdown]
# **Bivariate (graphical and non-graphical)**
#
#
#
# ---
# ![bar chart showing how alone effects survival.png](data:image/png;base64,...)![bar chart sowing how each class faired in survivability.png](data:image/png;base64,...)![bar chart comparing the alone levels of all three classes.png](data:image/png;base64,...)![bar chart showing how alone and class effect survival.png](data:image/png;base64,...)

# %% [markdown]
# These plots all confirm that being alone had a lower chance of survival while the better the class the better the chance of survival. For instance, plot 2 shows that survival by class was: first, second, third.

# %% [markdown]
# **The statistical model for this analysis is:**
#
# Survived = Class + Alone
#
# $\color{green}{\text{Variables:  }}$ survived, class, alone
#
# $\color{green}{\text{Model:  }}$ Multiple logistic regression
#
# $\color{green}{\text{Response Variable:  }}$ Survived - Categorical (0 = False, 1 = True)
#
# $\color{green}{\text{Predictor Variable:  }}$: Class, alone (all categorical)
#
# **Logistic Regression Assumptions:**

# %% [markdown]
# 1.      $\color{blue}{\text{Appropriate outcome type:  }}$
#
# The logistic regression type used (binary, multinomial, or ordinal) must correspond to the outcome (dependent) variable in the dataset.

# %% [markdown]
# Conclusion: Although the dytpe is int64, the only options are 0 and 1 (no/yes) and therefore meet the assumption.

# %% [markdown]
# 2.      $\color{blue}{\text{Linearity of independent variables and log-odds:  }}$
#
# The relationship between the logit (aka log-odds) of the outcome and each continuous independent variable is linear.

# %% [markdown]
# ![linearity.png](data:image/png;base64,...)

# %% [markdown]
# Evidence Checked: We can check for this using the Harvey collier test and regplot.
#
# Conclusion: The straight, relatively horizontal line provides good evidence of the linearity of the residuals. Furthermore, statistic=-0.5136335476486579 and the pvalue=0.6076364267751069, which greater than 0.05 which means linearity is met.

# %% [markdown]
# 3.     $\color{blue}{\text{ No strongly influential outliers:  }}$
#
#
# Logistic regression presupposes that no highly influential outlier data points exist, as they alter the model's outcome and accuracy.

# %% [markdown]
# Evidence Checked: By checking if any resid_dev values were greater/less than 3 or -3
#
# Conclusion: None, therefore the assumption is met.

# %% [markdown]
# 4.     $\color{blue}{\text{ Absence of multicollinearity:  }}$
#
#
# Multicollinearity occurs when the data contains highly associated independent variables which can affect the accuracy of the estimated coefficient and thus makes the model less efficient and weaker.

# %% [markdown]
# vif = [1.0188073981156203, 1.0188073981156205]

# %% [markdown]
#
# Evidence Checked: In order to determine if X variables are correlated in a regression model obtain the 'Variance Inflation Factor (VIF)
#
# Conclusion: Multicollinearity not found

# %% [markdown]
# 5.     $\color{blue}{\text{ Independence of observations:  }}$
#
#
#
# The observations must be independent of each other, i.e., they should not come from repeated or paired data.
#
# Evidence Checked: The Titanic model dataset consists of individual passenger records.
#
# Conclusion: Thus, the independence assumption is automatically met.

# %% [markdown]
#
# 6.     $\color{blue}{\text{ Sufficiently large sample size:  }}$
#
# There should be an adequate number of observations for each independent variable in the dataset to avoid creating an overfit model.

# %% [markdown]
# Evidence Checked: My model takes in 889 observations (derivied from value_counts
#
# Conclusion:  889 is significant and meets the assumption.

# %% [markdown]
# ---
#
# # Results
#
# Each of these predicator values has a p-value of 0, which indicates they are very significant and impact survival greatly. Each test statistics is negative which indicate that these predicator variables are respectively, -5 and -9.12 standard deviations below the survival mean.
#
# The odds ratio for pclass is 0.443439. This is less than 1, which indicates as class increases survival decreases. Thus, the odds of surviving are .44 times as likely as the class increases by one unit. The odds ratio for alone is 0.471840. Therefore, the odds of surving are .47 times as likely when one is alone.
#
# The log likelihood is -529.02, which is low but without another model to compare to doesn’t mean much. However, the LLR p-value is incredibly small which indicates we can be very certain in the results of the model.
#
#
#
#
# ---

# %% [markdown]
# ---
#
# # Discussion
# This model shows that as class increases (1 -> 2 -> 3) and if a passenger embarked alone, the chances of survival would go down. This means to have the highest chance of surviving the Titanic sinking, one would have to be in first class and traveling with either a child or parent.
#
#
# ![The Relationship Between Survival and Alone by Class.png](data:image/png;base64,...)
#
# This plot shows this relationship with those in First class and not alone surviving the most and those in third class and alone surviving the least.
#
# These results can be misused by taking the alone variable at face value. For instance, while it is true that on average being alone made one more likely to not survive, to depended on the type of relationship. For instance, parent/child relationships had a very high survival rate, while spouse/sibling relationships did not. Therefore, the data is somewhat skewed and to present it without a deeper understanding of why companionship increases survival would be ethically wrong.
#
# An interesting next step would be to look at how gender and what the relationship between passengers who travelled together was. For instance, most likely women and those with children would have a much higher survival rate than single men. This would simply be because women and children were prioritized oven men for lifeboats. Using logistic regression to confirm or reject this hypothesis would be very interesting.

# %% [markdown]
# ---
#
# # Appendix
# ---

# %% [markdown]
# Link to Data:
# https://drive.google.com/drive/folders/1siYt91K6nMMmBdvLuYvQRzJjSzqV9XWt

# %% [markdown]
# **Data Preparation**

# %%
#imports libraries useful/needed for logistic regression 
import statsmodels.api as sapi
import statsmodels.stats.api as sms
import seaborn as sns
import statsmodels.stats.outliers_influence as st_inf
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as mc
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
#mounts google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#imports csv file from google drive so it can be analyzed 

import pandas as pd
titanic = pd.read_csv("/content/drive/MyDrive/Data 0250/Titanic/titanic_data.csv")

#summary information on csv
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    object
#  3   age          713 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     887 non-null    object
#  8   class        889 non-null    object
#  9   adult_male   889 non-null    bool
#  10  deck         203 non-null    object
#  11  embark_town  887 non-null    object
#  12  alive        889 non-null    object
#  13  alone        889 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(6)
# memory usage: 85.2+ KB

# %%
#drops unneeded columns and creates new dataframe
titanic_cleaned = titanic.drop(["adult_male", "embark_town", "embarked", "alive", "fare", "deck", "parch", "sibsp", "sex", "age"], 1)
# Out:
# <ipython-input-4-482b5d7146ca>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   titanic_cleaned = titanic.drop(["adult_male", "embark_town", "embarked", "alive", "fare", "deck", "parch", "sibsp", "sex", "age"], 1)

# %%
#shows the effect of dropping nan values and how this redudces the observations
titanic_cleaned.dropna()
# Out:
#      survived  pclass   class  alone
# 0           0       3   Third  False
# 1           1       1   First  False
# 2           1       3   Third   True
# 3           1       1   First  False
# 4           0       3   Third   True
# ..        ...     ...     ...    ...
# 884         0       2  Second   True
# 885         1       1   First   True
# 886         0       3   Third  False
# 887         1       1   First   True
# 888         0       3   Third   True
#
# [889 rows x 4 columns]

# %%
#create duplicate of titanic_cleaned for later use in logsitic regression
titanic_cleaned_class = titanic_cleaned

# %%
#shows cleaned data (first five rows)
titanic_cleaned.head()
# Out:
#    survived  pclass  class  alone
# 0         0       3  Third  False
# 1         1       1  First  False
# 2         1       3  Third   True
# 3         1       1  First  False
# 4         0       3  Third   True

# %%
#Creates updated class column
titanic_cleaned['class_new'] = list(zip( titanic_cleaned['class'], titanic_cleaned.pclass,))
titanic_cleaned = titanic_cleaned.drop(["class", "pclass"], 1)
titanic_cleaned['class'] = titanic_cleaned['class_new']
titanic_cleaned = titanic_cleaned.drop(["class_new"], 1)
#prints first 5 rows of titanic_cleaned
titanic_cleaned.head()
# Out:
# <ipython-input-9-5f1dcea7e0a6>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   titanic_cleaned = titanic_cleaned.drop(["class", "pclass"], 1)
# <ipython-input-9-5f1dcea7e0a6>:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   titanic_cleaned = titanic_cleaned.drop(["class_new"], 1)
#    survived  alone       class
# 0         0  False  (Third, 3)
# 1         1  False  (First, 1)
# 2         1   True  (Third, 3)
# 3         1  False  (First, 1)
# 4         0   True  (Third, 3)

# %% [markdown]
# **EDA**

# %%
#shows value_counts of all catagorical variables
print(titanic_cleaned['class'].value_counts)
print(titanic_cleaned['alone'].value_counts)
print(titanic_cleaned['survived'].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0       (Third, 3)
# 1       (First, 1)
# 2       (Third, 3)
# 3       (First, 1)
# 4       (Third, 3)
#           ...
# 884    (Second, 2)
# 885     (First, 1)
# 886     (Third, 3)
# 887     (First, 1)
# 888     (Third, 3)
# Name: class, Length: 889, dtype: object>
# <bound method IndexOpsMixin.value_counts of 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 884     True
# 885     True
# 886    False
# 887     True
# 888     True
# Name: alone, Length: 889, dtype: bool>
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 884    0
# 885    1
# 886    0
# 887    1
# 888    0
# Name: survived, Length: 889, dtype: int64>

# %%
#sorts class variable by class
first_class = titanic.loc[titanic['pclass'] == 1]
second_class = titanic.loc[titanic['pclass'] == 2]
third_class = titanic.loc[titanic['pclass'] == 3]

# %%
#histogram of first class and how many people survived/died
first_class['survived'].plot(kind='hist', title="# of first Class Passengers that Survived")

# %%
#histogram of second class and how many people survived/died
second_class['survived'].plot(kind='hist', title="# of Second Class Passengers that Survived")

# %%
#histogram of third class and how many people survived/died
third_class['survived'].plot(kind='hist', title="# of Third Class Passengers that Survived")

# %%
#bar chart for class variable (shows how many were in each class)
titanic_cleaned_class['pclass'].value_counts().plot(kind = 'bar', x='class', y = 'Count', title="# of Passengers In each Class")

# %%
#bar chart for alone variable (shows how many were in alone)
titanic_cleaned.alone.value_counts().plot(kind = 'bar', x='alone', y = 'Count', title="How Many Passengers were Alone")

# %%
#bar chart for survived variable (shows how many survived)
titanic_cleaned.survived.value_counts().plot(kind = 'bar', x='survived', y = 'Count', title="# of Passengers Who Survived (1 = yes/ 0 = no)")

# %%
#covariance of all variables
titanic_cleaned_class.cov()
# Out:
#           survived    pclass     alone
# survived  0.236973 -0.137414 -0.048649
# pclass   -0.137414  0.699511  0.055632
# alone    -0.048649  0.055632  0.239676

# %%
#correlation of all variables
titanic_cleaned_class.corr()
# Out:
#           survived    pclass     alone
# survived  1.000000 -0.337508 -0.204132
# pclass   -0.337508  1.000000  0.135868
# alone    -0.204132  0.135868  1.000000

# %%
#correlation between alone and class
titanic_cleaned['alone'].corr(titanic['pclass'])
# Out:
# 0.1358683539471024

# %%
#covariance between alone and class
titanic_cleaned['alone'].cov(titanic_cleaned_class['pclass'])
# Out:
# 0.055632404057600976

# %%
#correlation between class and survived
titanic_cleaned_class['pclass'].corr(titanic_cleaned['survived'])
# Out:
# -0.33750830504438795

# %%
#covariance between class and survived
titanic_cleaned_class['pclass'].cov(titanic_cleaned['survived'])
# Out:
# -0.13741398879194136

# %%
#correlation between alone and survived
titanic_cleaned['alone'].corr(titanic_cleaned['survived'])

# %%
#covariance between alone and survived
titanic_cleaned['alone'].cov(titanic_cleaned['survived'])
# Out:
# -0.04864890199535878

# %%
#bar chart shwing how each class faired in survivability
sns.set(style='white')

sns.barplot(x='class', y='survived', hue='class', data=titanic_cleaned)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
#bar chart showing how alone and class effect survival

sns.set(style='white')

sns.barplot(x='alone', y='survived', hue='class', data=titanic_cleaned)
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
#bar chart showing how alone effects survival
sns.set(style='white')

sns.barplot(x='alone', y='survived', data=titanic_cleaned)
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
#bar chart comparing the alone levels of all three classes
sns.set(style='white')

sns.barplot(x='class', y='alone', hue='class', data=titanic_cleaned)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
#prints data types of all variables using titanic_cleaned_class
titanic_cleaned_class.dtypes
# Out:
# survived      int64
# pclass        int64
# class        object
# alone          bool
# class_new    object
# dtype: object

# %% [markdown]
# **Logistic Regression**

# %%
#Defines the formula for logistic regression and creates a model with a summary
formula_log2 = 'survived ~ pclass + alone'
log_model_2 = smf.logit(formula_log2, data=titanic_cleaned_class).fit()
log_model_2.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595073
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               survived   No. Observations:                  889
# Model:                          Logit   Df Residuals:                      886
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 28 Dec 2022   Pseudo R-squ.:                  0.1069
# Time:                        05:13:31   Log-Likelihood:                -529.02
# converged:                       True   LL-Null:                       -592.36
# Covariance Type:            nonrobust   LLR p-value:                 3.111e-28
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         1.8034      0.226      7.991      0.000       1.361       2.246
# alone[T.True]    -0.7511      0.150     -5.008      0.000      -1.045      -0.457
# pclass           -0.8132      0.088     -9.192      0.000      -0.987      -0.640
# =================================================================================
# """

# %%
#Creates a contingency table of the probabilities and the observed values.
titanic_cleaned['predictions'] = log_model_2.predict()
titanic_cleaned.loc[titanic_cleaned['predictions'] >= .50, 'Predicted'] = 1
titanic_cleaned.loc[titanic_cleaned['predictions'] < .50, 'Predicted'] = 0
data_crosstab = pd.crosstab(titanic_cleaned['Predicted'],
                            titanic_cleaned['survived'], 
                               margins = True)

print(data_crosstab)
# Out:
# survived     0    1  All
# Predicted
# 0.0        438  155  593
# 1.0        109  187  296
# All        547  342  889

# %%
#Creates the 'classification report'
print(classification_report((titanic_cleaned['survived']), titanic_cleaned['Predicted'].astype(float)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77       547
#            1       0.63      0.55      0.59       342
#
#     accuracy                           0.70       889
#    macro avg       0.69      0.67      0.68       889
# weighted avg       0.70      0.70      0.70       889

# %%
#Produce the 'odds ratio' for the model to be able to interpret the model coefficients
params = log_model_2.params
conf = log_model_2.conf_int()
conf['Odds Ratio'] = params
conf.columns = ['5%', '95%', 'Odds Ratio']
print(np.exp(conf))
# Out:
#                      5%       95%  Odds Ratio
# Intercept      3.900356  9.446911    6.070117
# alone[T.True]  0.351658  0.633094    0.471840
# pclass         0.372849  0.527393    0.443439

# %% [markdown]
# **Logistic Regression Assumptions Tests:**

# %%
#prints dtype of survived column
titanic_cleaned['survived'].dtypes
# Out:
# dtype('int64')

# %%
#Check linearity by examining the 'fitted values'
sns.regplot(log_model_2.fittedvalues, log_model_2.resid_dev)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#harvey collier test for linearity 
sms.linear_harvey_collier(log_model_2)
# Out:
# Ttest_1sampResult(statistic=-0.5136335476486633, pvalue=0.6076364267751031)

# %%
#create new column with resid_dev values
titanic_cleaned_class['residuals'] = log_model_2.resid_pearson

#filters column (resid_dev) by values and selects rows that match criteria
extreme_values_negative = titanic_cleaned_class.loc[(titanic_cleaned_class['residuals'] <= -3)]
extreme_values_positive = titanic_cleaned_class.loc[(titanic_cleaned_class['residuals'] >= 3)]

#shows all values that are greater than 3 within standard_resid column
extreme_values_negative
# Out:
# Empty DataFrame
# Columns: [survived, pclass, class, alone, class_new, residuals]
# Index: []

# %%
#shows all values that are greater than 3 within resid_dev column
extreme_values_positive
# Out:
# Empty DataFrame
# Columns: [survived, pclass, class, alone, class_new, residuals]
# Index: []

# %%
#Check for multicollinearity
variables = log_model_2.model.exog
vif = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
#adding the [1:] drops the VIF for the constant which is irrelevant
vif[1:]
# Out:
# [1.0188073981156203, 1.0188073981156205]

# %%
# Getting total number of observations
print(len(titanic_cleaned))
# Out:
# 889

# %% [markdown]
# **For Discussion Section**

# %%
#Creates a categorical interaction plot between survived and alone by class. 

ax = sns.pointplot(x="alone", y="survived", hue="class",
                   data=titanic_cleaned)
ax.set_ylabel('Survival Rate', fontsize=20)
ax.set_xlabel('Alone', fontsize=20)
ax.set_title('The Relationship Between Survival and Alone by Class', fontsize=20)
ax.legend(loc='upper right')
